# %% [markdown]
# 1) Data Preprocessing using openCV
# (Convert a video into frames)

# %%
import cv2

# Load the video file
video_path = "Source/videoplayback.mp4"
cap = cv2.VideoCapture(video_path)

frame_count = 0
frames = []
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frames.append(frame)
    frame_count += 1

cap.release()
print(f"Extracted {frame_count} frames from the video.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 10
#       8 frames = []
#       9 while True:
# ---> 10     ret, frame = cap.read()
#      11     if not ret:
#      12         break
#
# KeyboardInterrupt:

# %% [markdown]
# 2.Object Detection using YOLO (Detect vehicles in each frame)

# %%
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# Detect objects in each frame
detected_frames = []
for idx, frame in enumerate(frames):
    # YOLO inference
    results = model(frame, verbose=False)

    # Annotate frame with detected objects
    annotated_frame = results[0].plot()
    detected_frames.append(annotated_frame)

    print(f"Processed frame {idx + 1}/{frame_count}")

print("Object detection completed.")
# Out:
# Processed frame 1/716
# Processed frame 2/716
# Processed frame 3/716
# Processed frame 4/716
# Processed frame 5/716
# Processed frame 6/716
# Processed frame 7/716
# Processed frame 8/716
# Processed frame 9/716
# Processed frame 10/716
# Processed frame 11/716
# Processed frame 12/716
# Processed frame 13/716
# Processed frame 14/716
# Processed frame 15/716
# Processed frame 16/716
# Processed frame 17/716
# Processed frame 18/716
# Processed frame 19/716
# Processed frame 20/716
# Processed frame 21/716
# Processed frame 22/716
# Processed frame 23/716
# Processed frame 24/716
# Processed frame 25/716
# Processed frame 26/716
# Processed frame 27/716
# Processed frame 28/716
# Processed frame 29/716
# Processed frame 30/716
# Processed frame 31/716
# Processed frame 32/716
# Processed frame 33/716
# Processed frame 34/716
# Processed frame 35/716
# Processed frame 36/716
# Processed frame 37/716
# Processed frame 38/716
# Processed frame 39/716
# Processed frame 40/716
# Processed frame 41/716
# Processed frame 42/716
# Processed frame 43/716
# Processed frame 44/716
# Processed frame 45/716
# Processed frame 46/716
# Processed frame 47/716
# Processed frame 48/716
# Processed frame 49/716
# Processed frame 50/716
# Processed frame 51/716
# Processed frame 52/716
# Processed frame 53/716
# Processed frame 54/716
# Processed frame 55/716
# Processed frame 56/716
# Processed frame 57/716
# Processed frame 58/716
# Processed frame 59/716
# Processed frame 60/716
# Processed frame 61/716
# Processed frame 62/716
# Processed frame 63/716
# Processed frame 64/716
# Processed frame 65/716
# Processed frame 66/716
# Processed frame 67/716
# Processed frame 68/716
# Processed frame 69/716
# Processed frame 70/716
# Processed frame 71/716
# Processed frame 72/716
# Processed frame 73/716
# Processed frame 74/716
# Processed frame 75/716
# Processed frame 76/716
# Processed frame 77/716
# Processed frame 78/716
# Processed frame 79/716
# Processed frame 80/716
# Processed frame 81/716
# Processed frame 82/716
# Processed frame 83/716
# Processed frame 84/716
# Processed frame 85/716
# Processed frame 86/716
# Processed frame 87/716
# Processed frame 88/716
# Processed frame 89/716
# Processed frame 90/716
# Processed frame 91/716
# Processed frame 92/716
# Processed frame 93/716
# Processed frame 94/716
# Processed frame 95/716
# Processed frame 96/716
# Processed frame 97/716
# Processed frame 98/716
# Processed frame 99/716
# Processed frame 100/716
# Processed frame 101/716
# Processed frame 102/716
# Processed frame 103/716
# Processed frame 104/716
# Processed frame 105/716
# Processed frame 106/716
# Processed frame 107/716
# Processed frame 108/716
# Processed frame 109/716
# Processed frame 110/716
# Processed frame 111/716
# Processed frame 112/716
# Processed frame 113/716
# Processed frame 114/716
# Processed frame 115/716
# Processed frame 116/716
# Processed frame 117/716
# Processed frame 118/716
# Processed frame 119/716
# Processed frame 120/716
# Processed frame 121/716
# Processed frame 122/716
# Processed frame 123/716
# Processed frame 124/716
# Processed frame 125/716
# Processed frame 126/716
# Processed frame 127/716
# Processed frame 128/716
# Processed frame 129/716
# Processed frame 130/716
# Processed frame 131/716
# Processed frame 132/716
# Processed frame 133/716
# Processed frame 134/716
# Processed frame 135/716
# Processed frame 136/716
# Processed frame 137/716
# Processed frame 138/716
# Processed frame 139/716
# Processed frame 140/716
# Processed frame 141/716
# Processed frame 142/716
# Processed frame 143/716
# Processed frame 144/716
# Processed frame 145/716
# Processed frame 146/716
# Processed frame 147/716
# Processed frame 148/716
# Processed frame 149/716
# Processed frame 150/716
# Processed frame 151/716
# Processed frame 152/716
# Processed frame 153/716
# Processed frame 154/716
# Processed frame 155/716
# Processed frame 156/716
# Processed frame 157/716
# Processed frame 158/716
# Processed frame 159/716
# Processed frame 160/716
# Processed frame 161/716
# Processed frame 162/716
# Processed frame 163/716
# Processed frame 164/716
# Processed frame 165/716
# Processed frame 166/716
# Processed frame 167/716
# Processed frame 168/716
# Processed frame 169/716
# Processed frame 170/716
# Processed frame 171/716
# Processed frame 172/716
# Processed frame 173/716
# Processed frame 174/716
# Processed frame 175/716
# Processed frame 176/716
# Processed frame 177/716
# Processed frame 178/716
# Processed frame 179/716
# Processed frame 180/716
# Processed frame 181/716
# Processed frame 182/716
# Processed frame 183/716
# Processed frame 184/716
# Processed frame 185/716
# Processed frame 186/716
# Processed frame 187/716
# Processed frame 188/716
# Processed frame 189/716
# Processed frame 190/716
# Processed frame 191/716
# Processed frame 192/716
# Processed frame 193/716
# Processed frame 194/716
# Processed frame 195/716
# Processed frame 196/716
# Processed frame 197/716
# Processed frame 198/716
# Processed frame 199/716
# Processed frame 200/716
# Processed frame 201/716
# Processed frame 202/716
# Processed frame 203/716
# Processed frame 204/716
# Processed frame 205/716
# Processed frame 206/716
# Processed frame 207/716
# Processed frame 208/716
# Processed frame 209/716
# Processed frame 210/716
# Processed frame 211/716
# Processed frame 212/716
# Processed frame 213/716
# Processed frame 214/716
# Processed frame 215/716
# Processed frame 216/716
# Processed frame 217/716
# Processed frame 218/716
# Processed frame 219/716
# Processed frame 220/716
# Processed frame 221/716
# Processed frame 222/716
# Processed frame 223/716
# Processed frame 224/716
# Processed frame 225/716
# Processed frame 226/716
# Processed frame 227/716
# Processed frame 228/716
# Processed frame 229/716
# Processed frame 230/716
# Processed frame 231/716
# Processed frame 232/716
# Processed frame 233/716
# Processed frame 234/716
# Processed frame 235/716
# Processed frame 236/716
# Processed frame 237/716
# Processed frame 238/716
# Processed frame 239/716
# Processed frame 240/716
# Processed frame 241/716
# Processed frame 242/716
# Processed frame 243/716
# Processed frame 244/716
# Processed frame 245/716
# Processed frame 246/716
# Processed frame 247/716
# Processed frame 248/716
# Processed frame 249/716
# Processed frame 250/716
# Processed frame 251/716
# Processed frame 252/716
# Processed frame 253/716
# Processed frame 254/716
# Processed frame 255/716
# Processed frame 256/716
# Processed frame 257/716
# Processed frame 258/716
# Processed frame 259/716
# Processed frame 260/716
# Processed frame 261/716
# Processed frame 262/716
# Processed frame 263/716
# Processed frame 264/716
# Processed frame 265/716
# Processed frame 266/716
# Processed frame 267/716
# Processed frame 268/716
# Processed frame 269/716
# Processed frame 270/716
# Processed frame 271/716
# Processed frame 272/716
# Processed frame 273/716
# Processed frame 274/716
# Processed frame 275/716
# Processed frame 276/716
# Processed frame 277/716
# Processed frame 278/716
# Processed frame 279/716
# Processed frame 280/716
# Processed frame 281/716
# Processed frame 282/716
# Processed frame 283/716
# Processed frame 284/716
# Processed frame 285/716
# Processed frame 286/716
# Processed frame 287/716
# Processed frame 288/716
# Processed frame 289/716
# Processed frame 290/716
# Processed frame 291/716
# Processed frame 292/716
# Processed frame 293/716
# Processed frame 294/716
# Processed frame 295/716
# Processed frame 296/716
# Processed frame 297/716
# Processed frame 298/716
# Processed frame 299/716
# Processed frame 300/716
# Processed frame 301/716
# Processed frame 302/716
# Processed frame 303/716
# Processed frame 304/716
# Processed frame 305/716
# Processed frame 306/716
# Processed frame 307/716
# Processed frame 308/716
# Processed frame 309/716
# Processed frame 310/716
# Processed frame 311/716
# Processed frame 312/716
# Processed frame 313/716
# Processed frame 314/716
# Processed frame 315/716
# Processed frame 316/716
# Processed frame 317/716
# Processed frame 318/716
# Processed frame 319/716
# Processed frame 320/716
# Processed frame 321/716
# Processed frame 322/716
# Processed frame 323/716
# Processed frame 324/716
# Processed frame 325/716
# Processed frame 326/716
# Processed frame 327/716
# Processed frame 328/716
# Processed frame 329/716
# Processed frame 330/716
# Processed frame 331/716
# Processed frame 332/716
# Processed frame 333/716
# Processed frame 334/716
# Processed frame 335/716
# Processed frame 336/716
# Processed frame 337/716
# Processed frame 338/716
# Processed frame 339/716
# Processed frame 340/716
# Processed frame 341/716
# Processed frame 342/716
# Processed frame 343/716
# Processed frame 344/716
# Processed frame 345/716
# Processed frame 346/716
# Processed frame 347/716
# Processed frame 348/716
# Processed frame 349/716
# Processed frame 350/716
# Processed frame 351/716
# Processed frame 352/716
# Processed frame 353/716
# Processed frame 354/716
# Processed frame 355/716
# Processed frame 356/716
# Processed frame 357/716
# Processed frame 358/716
# Processed frame 359/716
# Processed frame 360/716
# Processed frame 361/716
# Processed frame 362/716
# Processed frame 363/716
# Processed frame 364/716
# Processed frame 365/716
# Processed frame 366/716
# Processed frame 367/716
# Processed frame 368/716
# Processed frame 369/716
# Processed frame 370/716
# Processed frame 371/716
# Processed frame 372/716
# Processed frame 373/716
# Processed frame 374/716
# Processed frame 375/716
# Processed frame 376/716
# Processed frame 377/716
# Processed frame 378/716
# Processed frame 379/716
# Processed frame 380/716
# Processed frame 381/716
# Processed frame 382/716
# Processed frame 383/716
# Processed frame 384/716
# Processed frame 385/716
# Processed frame 386/716
# Processed frame 387/716
# Processed frame 388/716
# Processed frame 389/716
# Processed frame 390/716
# Processed frame 391/716
# Processed frame 392/716
# Processed frame 393/716
# Processed frame 394/716
# Processed frame 395/716
# Processed frame 396/716
# Processed frame 397/716
# Processed frame 398/716
# Processed frame 399/716
# Processed frame 400/716
# Processed frame 401/716
# Processed frame 402/716
# Processed frame 403/716
# Processed frame 404/716
# Processed frame 405/716
# Processed frame 406/716
# Processed frame 407/716
# Processed frame 408/716
# Processed frame 409/716
# Processed frame 410/716
# Processed frame 411/716
# Processed frame 412/716
# Processed frame 413/716
# Processed frame 414/716
# Processed frame 415/716
# Processed frame 416/716
# Processed frame 417/716
# Processed frame 418/716
# Processed frame 419/716
# Processed frame 420/716
# Processed frame 421/716
# Processed frame 422/716
# Processed frame 423/716
# Processed frame 424/716
# Processed frame 425/716
# Processed frame 426/716
# Processed frame 427/716
# Processed frame 428/716
# Processed frame 429/716
# Processed frame 430/716
# Processed frame 431/716
# Processed frame 432/716
# Processed frame 433/716
# Processed frame 434/716
# Processed frame 435/716
# Processed frame 436/716
# Processed frame 437/716
# Processed frame 438/716
# Processed frame 439/716
# Processed frame 440/716
# Processed frame 441/716
# Processed frame 442/716
# Processed frame 443/716
# Processed frame 444/716
# Processed frame 445/716
# Processed frame 446/716
# Processed frame 447/716
# Processed frame 448/716
# Processed frame 449/716
# Processed frame 450/716
# Processed frame 451/716
# Processed frame 452/716
# Processed frame 453/716
# Processed frame 454/716
# Processed frame 455/716
# Processed frame 456/716
# Processed frame 457/716
# Processed frame 458/716
# Processed frame 459/716
# Processed frame 460/716
# Processed frame 461/716
# Processed frame 462/716
# Processed frame 463/716
# Processed frame 464/716
# Processed frame 465/716
# Processed frame 466/716
# Processed frame 467/716
# Processed frame 468/716
# Processed frame 469/716
# Processed frame 470/716
# Processed frame 471/716
# Processed frame 472/716
# Processed frame 473/716
# Processed frame 474/716
# Processed frame 475/716
# Processed frame 476/716
# Processed frame 477/716
# Processed frame 478/716
# Processed frame 479/716
# Processed frame 480/716
# Processed frame 481/716
# Processed frame 482/716
# Processed frame 483/716
# Processed frame 484/716
# Processed frame 485/716
# Processed frame 486/716
# Processed frame 487/716
# Processed frame 488/716
# Processed frame 489/716
# Processed frame 490/716
# Processed frame 491/716
# Processed frame 492/716
# Processed frame 493/716
# Processed frame 494/716
# Processed frame 495/716
# Processed frame 496/716
# Processed frame 497/716
# Processed frame 498/716
# Processed frame 499/716
# Processed frame 500/716
# Processed frame 501/716
# Processed frame 502/716
# Processed frame 503/716
# Processed frame 504/716
# Processed frame 505/716
# Processed frame 506/716
# Processed frame 507/716
# Processed frame 508/716
# Processed frame 509/716
# Processed frame 510/716
# Processed frame 511/716
# Processed frame 512/716
# Processed frame 513/716
# Processed frame 514/716
# Processed frame 515/716
# Processed frame 516/716
# Processed frame 517/716
# Processed frame 518/716
# Processed frame 519/716
# Processed frame 520/716
# Processed frame 521/716
# Processed frame 522/716
# Processed frame 523/716
# Processed frame 524/716
# Processed frame 525/716
# Processed frame 526/716
# Processed frame 527/716
# Processed frame 528/716
# Processed frame 529/716
# Processed frame 530/716
# Processed frame 531/716
# Processed frame 532/716
# Processed frame 533/716
# Processed frame 534/716
# Processed frame 535/716
# Processed frame 536/716
# Processed frame 537/716
# Processed frame 538/716
# Processed frame 539/716
# Processed frame 540/716
# Processed frame 541/716
# Processed frame 542/716
# Processed frame 543/716
# Processed frame 544/716
# Processed frame 545/716
# Processed frame 546/716
# Processed frame 547/716
# Processed frame 548/716
# Processed frame 549/716
# Processed frame 550/716
# Processed frame 551/716
# Processed frame 552/716
# Processed frame 553/716
# Processed frame 554/716
# Processed frame 555/716
# Processed frame 556/716
# Processed frame 557/716
# Processed frame 558/716
# Processed frame 559/716
# Processed frame 560/716
# Processed frame 561/716
# Processed frame 562/716
# Processed frame 563/716
# Processed frame 564/716
# Processed frame 565/716
# Processed frame 566/716
# Processed frame 567/716
# Processed frame 568/716
# Processed frame 569/716
# Processed frame 570/716
# Processed frame 571/716
# Processed frame 572/716
# Processed frame 573/716
# Processed frame 574/716
# Processed frame 575/716
# Processed frame 576/716
# Processed frame 577/716
# Processed frame 578/716
# Processed frame 579/716
# Processed frame 580/716
# Processed frame 581/716
# Processed frame 582/716
# Processed frame 583/716
# Processed frame 584/716
# Processed frame 585/716
# Processed frame 586/716
# Processed frame 587/716
# Processed frame 588/716
# Processed frame 589/716
# Processed frame 590/716
# Processed frame 591/716
# Processed frame 592/716
# Processed frame 593/716
# Processed frame 594/716
# Processed frame 595/716
# Processed frame 596/716
# Processed frame 597/716
# Processed frame 598/716
# Processed frame 599/716
# Processed frame 600/716
# Processed frame 601/716
# Processed frame 602/716
# Processed frame 603/716
# Processed frame 604/716
# Processed frame 605/716
# Processed frame 606/716
# Processed frame 607/716
# Processed frame 608/716
# Processed frame 609/716
# Processed frame 610/716
# Processed frame 611/716
# Processed frame 612/716
# Processed frame 613/716
# Processed frame 614/716
# Processed frame 615/716
# Processed frame 616/716
# Processed frame 617/716
# Processed frame 618/716
# Processed frame 619/716
# Processed frame 620/716
# Processed frame 621/716
# Processed frame 622/716
# Processed frame 623/716
# Processed frame 624/716
# Processed frame 625/716
# Processed frame 626/716
# Processed frame 627/716
# Processed frame 628/716
# Processed frame 629/716
# Processed frame 630/716
# Processed frame 631/716
# Processed frame 632/716
# Processed frame 633/716
# Processed frame 634/716
# Processed frame 635/716
# Processed frame 636/716
# Processed frame 637/716
# Processed frame 638/716
# Processed frame 639/716
# Processed frame 640/716
# Processed frame 641/716
# Processed frame 642/716
# Processed frame 643/716
# Processed frame 644/716
# Processed frame 645/716
# Processed frame 646/716
# Processed frame 647/716
# Processed frame 648/716
# Processed frame 649/716
# Processed frame 650/716
# Processed frame 651/716
# Processed frame 652/716
# Processed frame 653/716
# Processed frame 654/716
# Processed frame 655/716
# Processed frame 656/716
# Processed frame 657/716
# Processed frame 658/716
# Processed frame 659/716
# Processed frame 660/716
# Processed frame 661/716
# Processed frame 662/716
# Processed frame 663/716
# Processed frame 664/716
# Processed frame 665/716
# Processed frame 666/716
# Processed frame 667/716
# Processed frame 668/716
# Processed frame 669/716
# Processed frame 670/716
# Processed frame 671/716
# Processed frame 672/716
# Processed frame 673/716
# Processed frame 674/716
# Processed frame 675/716
# Processed frame 676/716
# Processed frame 677/716
# Processed frame 678/716
# Processed frame 679/716
# Processed frame 680/716
# Processed frame 681/716
# Processed frame 682/716
# Processed frame 683/716
# Processed frame 684/716
# Processed frame 685/716
# Processed frame 686/716
# Processed frame 687/716
# Processed frame 688/716
# Processed frame 689/716
# Processed frame 690/716
# Processed frame 691/716
# Processed frame 692/716
# Processed frame 693/716
# Processed frame 694/716
# Processed frame 695/716
# Processed frame 696/716
# Processed frame 697/716
# Processed frame 698/716
# Processed frame 699/716
# Processed frame 700/716
# Processed frame 701/716
# Processed frame 702/716
# Processed frame 703/716
# Processed frame 704/716
# Processed frame 705/716
# Processed frame 706/716
# Processed frame 707/716
# Processed frame 708/716
# Processed frame 709/716
# Processed frame 710/716
# Processed frame 711/716
# Processed frame 712/716
# Processed frame 713/716
# Processed frame 714/716
# Processed frame 715/716
# Processed frame 716/716
# Object detection completed.

# %% [markdown]
# 3. Extracting Bounding box width

# %%
# Extract bounding box width
for result in results:
    boxes = result.boxes
    for box in boxes:
        x_min, y_min, x_max, y_max = box.xyxy[0].tolist()  # Get coordinates in (x_min, y_min, x_max, y_max) format
        bbox_width = x_max - x_min  # Calculate bounding box width in pixels
        print(f"Bounding Box Width: {bbox_width} pixels")
# Out:
# Bounding Box Width: 74.4959716796875 pixels
# Bounding Box Width: 67.7984619140625 pixels
# Bounding Box Width: 114.96168518066406 pixels
# Bounding Box Width: 77.26904296875 pixels
# Bounding Box Width: 143.91998291015625 pixels
# Bounding Box Width: 53.7501220703125 pixels
# Bounding Box Width: 556.792236328125 pixels
# Bounding Box Width: 45.3662109375 pixels
# Bounding Box Width: 48.8248291015625 pixels
# Bounding Box Width: 43.9747314453125 pixels
# Bounding Box Width: 44.6851806640625 pixels
# Bounding Box Width: 43.746826171875 pixels

# %% [markdown]
# 4.Getting Calculate Scale

# %%
"""bbox_width = width of a bounding box pixels and real_world_width is the width of the object in real world"""
import numpy as np
def calculate_scale(bbox_width, real_world_width=2.0):
    return real_world_width / bbox_width
bbox_widths = [782.13, 196.79, 140.25, 123.45, 63.00, 32.49, 999.59, 394.61, 84.87]

# Calculate median bbox width
bbox_width = np.median(bbox_widths)
scale = calculate_scale(bbox_width)
print(f"Scale factor: {scale} meters per pixel")
# Out:
# Scale factor: 0.0142602495543672 meters per pixel

# %% [markdown]
# 5.Calibration(Convert pixel distances to meters)

# %%
def estimate_road_width(bboxes, scale):

    x_positions = [bbox[0] for bbox in bboxes] + [bbox[2] for bbox in bboxes]
    road_width_pixels = max(x_positions) - min(x_positions)
    road_width_meters = road_width_pixels * scale
    return road_width_meters

cap = cv2.VideoCapture(video_path)

ret, frame = cap.read()
results = model(frame)

# Extract bounding box coordinates
bboxes = []  # List to store bounding box coordinates
for result in results:
    boxes = result.boxes  # Detected boxes
    for box in boxes:
        # Extract coordinates (x_min, y_min, x_max, y_max) as integers
        x_min, y_min, x_max, y_max = map(int, box.xyxy[0].tolist())
        bboxes.append([x_min, y_min, x_max, y_max])  # Append bbox to the list

scale =0.0142602495543672  #scale factor (meters per pixel)

# Estimate road width
road_width = estimate_road_width(bboxes, scale)

# Print results
print(f"Bounding Boxes: {bboxes}")
print(f"Estimated Road Width: {road_width} meters")

# Release the video capture
cap.release()
# Out:
# Bounding Boxes: [[1251, 46, 1384, 169], [1060, 404, 1372, 797], [1251, 48, 1386, 170], [1060, 402, 1372, 797]]
# Estimated Road Width: 4.648841354723707 meters

# %% [markdown]
# 6.Visualization

# %%
for idx, frame in enumerate(detected_frames):
    # Add road width text
    cv2.putText(frame, f"Road Width: {road_width:.2f} meters", (50, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Display the frame
    cv2.imshow("Frame", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

# %% [markdown]
# 7.Saving Result

# %%
# Save video
output_path = "output_video.mp4"
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
height, width, _ = detected_frames[0].shape
out = cv2.VideoWriter(output_path, fourcc, 30, (width, height))

for frame in detected_frames:
    out.write(frame)

out.release()
print("Processed video saved.")

with open("road_width_results.txt", "w") as f:
    f.write(f"Estimated Road Width: {road_width:.2f} meters\n")
print("Results saved.")
# Out:
# Processed video saved.
# Results saved.
